# %%
from dotenv import load_dotenv
import os
from openai import OpenAI

load_dotenv()
# Out:
# True

# %%
# Validar que se lee la API correctamente
# print(os.getenv("OPENAI_API_KEY"))

# %%
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
response = client.responses.create(
    model="gpt-5.4-mini",
    input="Di hola en francés"
)

print(response.output[0].content[0].text)
# Out:
# Bonjour.

# %%
fact = client.responses.create(
        model="gpt-4.1-mini",
        input="Dame un dato breve (1-2 líneas) interesante sobre moda"

    
    )

dato_curioso = fact.output[0].content[0].text
print(dato_curioso)
# Out:
# El color púrpura era tan raro y caro en la antigüedad que solo la realeza y la nobleza podían usarlo como símbolo de poder y prestigio.
